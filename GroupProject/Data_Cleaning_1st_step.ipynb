# 128185    15000.0      15000.0          15000.0   60 months   18.45%
# 128186    15000.0      15000.0          15000.0   36 months   15.49%
# 128187     5000.0       5000.0           5000.0   36 months   10.56%
# 128188     5000.0       5000.0           5000.0   36 months   16.46%
# 128189    12000.0      12000.0          12000.0   36 months   14.03%
# 128190     5000.0       5000.0           5000.0   36 months    6.19%
# 128191    10000.0      10000.0          10000.0   36 months   11.05%
# 128192    20000.0      20000.0          20000.0   36 months   15.49%
# 128193     4000.0       4000.0           4000.0   36 months   16.46%
# 128194        NaN          NaN              NaN         NaN      NaN
# 128195        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade                       emp_title  \
# 0            307.27     A        A2            Customer Service Rep
# 1            770.63     B        B4          Associate Director, IT
# 2            300.13     A        A4                 Branch manager
# 3            557.52     A        A3               Sr. Project Buyer
# 4            378.59     A        A5                         janitor
# 5            154.87     A        A3                             NaN
# 6            395.95     A        A5                  Company driver
# 7            750.83     D        D2              Home Care Provided
# 8            614.53     A        A2      Systems Administrator Lead
# 9            176.14     C        C4                          Driver
# 10           571.22     C        C3            Marketing specialist
# 11           388.62     D        D2                  shipping clerk
# 12           292.46     C        C2    Assistant Manager E-Commerce
# 13          1075.43     A        A2                 Service Advisor
# 14           658.36     C        C2     Customer Service Supervisor
# 15           556.37     D        D5           Relationship Manager
# 16           707.00     A        A4                         Manager
# 17           189.30     A        A5                        Waitress
# 18           157.10     A        A4                      Doc Worker
# 19           346.76     C        C3              Teachers Assistant
# 20           350.15     A        A4  UB APPLICATION SUPPORT ANALYST
# 21           614.53     A        A2                 General Manager
# 22           357.01     C        C3                     Salesperson
# 23           460.82     C        C1               Director of Sales
# 24           365.67     A        A1              PACS Imaging Tech.
# 25           285.61     C        C3                   IT Specialist
# 26           206.76     B        B1       Sales Engineering Support
# 27           316.80     B        B4              Operations Manager
# 28           792.27     A        A1                             CEO
# 29           569.01     C        C2                             NaN
# ...             ...   ...       ...                             ...
# 128166       346.77     C        C5                      supervisor
# 128167       655.25     B        B4                           owner
# 128168       533.59     D        D5                             NaN
# 128169      1204.42     A        A1                        Director
# 128170       698.12     C        C4                       Paralegal
# 128171       932.64     A        A4                 Sales Estimater
# 128172      1083.98     A        A1                 Retail Director
# 128173       862.39     A        A3                Regional manager
# 128174       696.16     B        B3                             NaN
# 128175       849.23     C        C5                Registered Nurse
# 128176       760.72     A        A4   Produce buyer - merchandiser
# 128177       690.24     A        A3                              RN
# 128178       522.42     B        B4                             NaN
# 128179       325.31     B        B3                   Bailbondsman
# 128180       508.36     E        E3                             NaN
# 128181       655.25     B        B4      Student Support Specialist
# 128182       332.77     B        B5                  Night watchman
# 128183       323.01     B        B2                     Pipe Fitter
# 128184       911.36     C        C1              Marketing manager
# 128185       384.59     D        D2                             NaN
# 128186       523.59     C        C4                     Crew leader
# 128187       162.66     B        B3                             NaN
# 128188       176.93     C        C5                    Labor Worker
# 128189       410.31     C        C2           Medical Support Staff
# 128190       152.55     A        A2                    Host/cashier
# 128191       327.63     B        B4                        Operator
# 128192       698.12     C        C4                  Client manager
# 128193       141.54     C        C5                         jewelry
# 128194          NaN   NaN       NaN                             NaN
# 128195          NaN   NaN       NaN                             NaN
#
#        emp_length  ... hardship_payoff_balance_amount  \
# 0       10+ years  ...                            NaN
# 1       10+ years  ...                            NaN
# 2         3 years  ...                            NaN
# 3       10+ years  ...                            NaN
# 4         3 years  ...                            NaN
# 5             NaN  ...                            NaN
# 6         2 years  ...                            NaN
# 7         6 years  ...                            NaN
# 8         4 years  ...                            NaN
# 9       10+ years  ...                            NaN
# 10         1 year  ...                            NaN
# 11      10+ years  ...                            NaN
# 12        2 years  ...                            NaN
# 13        4 years  ...                            NaN
# 14      10+ years  ...                            NaN
# 15        2 years  ...                            NaN
# 16      10+ years  ...                            NaN
# 17      10+ years  ...                            NaN
# 18         1 year  ...                            NaN
# 19        2 years  ...                            NaN
# 20        8 years  ...                            NaN
# 21       < 1 year  ...                            NaN
# 22      10+ years  ...                            NaN
# 23       < 1 year  ...                            NaN
# 24      10+ years  ...                            NaN
# 25      10+ years  ...                            NaN
# 26         1 year  ...                            NaN
# 27        8 years  ...                            NaN
# 28      10+ years  ...                            NaN
# 29            NaN  ...                            NaN
# ...           ...  ...                            ...
# 128166    8 years  ...                            NaN
# 128167  10+ years  ...                            NaN
# 128168        NaN  ...                            NaN
# 128169    8 years  ...                            NaN
# 128170    4 years  ...                            NaN
# 128171  10+ years  ...                            NaN
# 128172    5 years  ...                            NaN
# 128173    6 years  ...                            NaN
# 128174        NaN  ...                            NaN
# 128175    2 years  ...                            NaN
# 128176     1 year  ...                            NaN
# 128177  10+ years  ...                            NaN
# 128178        NaN  ...                            NaN
# 128179  10+ years  ...                            NaN
# 128180        NaN  ...                            NaN
# 128181  10+ years  ...                            NaN
# 128182  10+ years  ...                            NaN
# 128183    5 years  ...                            NaN
# 128184  10+ years  ...                            NaN
# 128185        NaN  ...                            NaN
# 128186  10+ years  ...                            NaN
# 128187        NaN  ...                            NaN
# 128188    3 years  ...                            NaN
# 128189  10+ years  ...                            NaN
# 128190    4 years  ...                            NaN
# 128191    5 years  ...                            NaN
# 128192  10+ years  ...                            NaN
# 128193    5 years  ...                            NaN
# 128194        NaN  ...                            NaN
# 128195        NaN  ...                            NaN
#
#         hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                                NaN           DirectPay                    N
# 1                                NaN                Cash                    N
# 2                                NaN                Cash                    N
# 3                                NaN                Cash                    N
# 4                                NaN                Cash                    N
# 5                                NaN                Cash                    N
# 6                                NaN                Cash                    N
# 7                                NaN                Cash                    N
# 8                                NaN                Cash                    N
# 9                                NaN                Cash                    N
# 10                               NaN                Cash                    N
# 11                               NaN                Cash                    N
# 12                               NaN                Cash                    N
# 13                               NaN                Cash                    N
# 14                               NaN                Cash                    N
# 15                               NaN                Cash                    N
# 16                               NaN                Cash                    N
# 17                               NaN                Cash                    N
# 18                               NaN           DirectPay                    N
# 19                               NaN                Cash                    N
# 20                               NaN                Cash                    N
# 21                               NaN                Cash                    N
# 22                               NaN                Cash                    N
# 23                               NaN                Cash                    N
# 24                               NaN           DirectPay                    N
# 25                               NaN                Cash                    N
# 26                               NaN                Cash                    N
# 27                               NaN                Cash                    N
# 28                               NaN           DirectPay                    N
# 29                               NaN                Cash                    N
# ...                              ...                 ...                  ...
# 128166                           NaN                Cash                    N
# 128167                           NaN                Cash                    N
# 128168                           NaN                Cash                    N
# 128169                           NaN           DirectPay                    N
# 128170                           NaN                Cash                    N
# 128171                           NaN                Cash                    N
# 128172                           NaN                Cash                    N
# 128173                           NaN                Cash                    N
# 128174                           NaN                Cash                    N
# 128175                           NaN                Cash                    N
# 128176                           NaN                Cash                    N
# 128177                           NaN           DirectPay                    N
# 128178                           NaN                Cash                    N
# 128179                           NaN                Cash                    N
# 128180                           NaN                Cash                    N
# 128181                           NaN                Cash                    N
# 128182                           NaN                Cash                    N
# 128183                           NaN                Cash                    N
# 128184                           NaN                Cash                    N
# 128185                           NaN                Cash                    N
# 128186                           NaN                Cash                    N
# 128187                           NaN                Cash                    N
# 128188                           NaN                Cash                    N
# 128189                           NaN                Cash                    N
# 128190                           NaN                Cash                    N
# 128191                           NaN                Cash                    N
# 128192                           NaN                Cash                    N
# 128193                           NaN                Cash                    N
# 128194                           NaN                 NaN                  NaN
# 128195                           NaN                 NaN                  NaN
#
#        debt_settlement_flag_date settlement_status  settlement_date  \
# 0                            NaN               NaN              NaN
# 1                            NaN               NaN              NaN
# 2                            NaN               NaN              NaN
# 3                            NaN               NaN              NaN
# 4                            NaN               NaN              NaN
# 5                            NaN               NaN              NaN
# 6                            NaN               NaN              NaN
# 7                            NaN               NaN              NaN
# 8                            NaN               NaN              NaN
# 9                            NaN               NaN              NaN
# 10                           NaN               NaN              NaN
# 11                           NaN               NaN              NaN
# 12                           NaN               NaN              NaN
# 13                           NaN               NaN              NaN
# 14                           NaN               NaN              NaN
# 15                           NaN               NaN              NaN
# 16                           NaN               NaN              NaN
# 17                           NaN               NaN              NaN
# 18                           NaN               NaN              NaN
# 19                           NaN               NaN              NaN
# 20                           NaN               NaN              NaN
# 21                           NaN               NaN              NaN
# 22                           NaN               NaN              NaN
# 23                           NaN               NaN              NaN
# 24                           NaN               NaN              NaN
# 25                           NaN               NaN              NaN
# 26                           NaN               NaN              NaN
# 27                           NaN               NaN              NaN
# 28                           NaN               NaN              NaN
# 29                           NaN               NaN              NaN
# ...                          ...               ...              ...
# 128166                       NaN               NaN              NaN
# 128167                       NaN               NaN              NaN
# 128168                       NaN               NaN              NaN
# 128169                       NaN               NaN              NaN
# 128170                       NaN               NaN              NaN
# 128171                       NaN               NaN              NaN
# 128172                       NaN               NaN              NaN
# 128173                       NaN               NaN              NaN
# 128174                       NaN               NaN              NaN
# 128175                       NaN               NaN              NaN
# 128176                       NaN               NaN              NaN
# 128177                       NaN               NaN              NaN
# 128178                       NaN               NaN              NaN
# 128179                       NaN               NaN              NaN
# 128180                       NaN               NaN              NaN
# 128181                       NaN               NaN              NaN
# 128182                       NaN               NaN              NaN
# 128183                       NaN               NaN              NaN
# 128184                       NaN               NaN              NaN
bursement_method debt_settlement_flag debt_settlement_flag_date  \
# 128194                 NaN                  NaN                       NaN
# 128195                 NaN                  NaN                       NaN
#
#        settlement_status  settlement_date  settlement_amount  \
# 128194               NaN              NaN                NaN
# 128195               NaN              NaN                NaN
#
#        settlement_percentage settlement_term
# 128194                   NaN             NaN
# 128195                   NaN             NaN
#
# [2 rows x 143 columns]

# %%
print(data[-2:].isna().values.all())
print(data[-2:].isna().sum().sum())
print(data[-3:-2].isna().any().sum())
# Out:
# True
# 286
# 43

# %% [markdown]
# The last two rows are all missing values (only 43 are missing in the last third row), drop them. The last two rows are missing in the original excel dataset

# %%
data.drop([128194,128195], axis=0, inplace=True)

# %%
data
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         10000.0      10000.0          10000.0   36 months    6.67%
# 1         35000.0      35000.0          35000.0   60 months   11.55%
# 2          9600.0       9600.0           9600.0   36 months    7.84%
# 3         18000.0      18000.0          18000.0   36 months    7.21%
# 4         12000.0      12000.0          12000.0   36 months    8.46%
# 5          5000.0       5000.0           5000.0   36 months    7.21%
# 6         12550.0      12550.0          12550.0   36 months    8.46%
# 7         20500.0      20500.0          20500.0   36 months   18.94%
# 8         20000.0      20000.0          20000.0   36 months    6.67%
# 9          5000.0       5000.0           5000.0   36 months   16.14%
# 10        24000.0      24000.0          24000.0   60 months   15.02%
# 11        15000.0      15000.0          15000.0   60 months   18.94%
# 12         8500.0       8500.0           8500.0   36 months   14.47%
# 13        35000.0      35000.0          35000.0   36 months    6.67%
# 14        28000.0      28000.0          28000.0   60 months   14.47%
# 15        20000.0      20000.0          20000.0   60 months   22.35%
# 16        35000.0      35000.0          35000.0   60 months    7.84%
# 17         6000.0       6000.0           6000.0   36 months    8.46%
# 18         5025.0       5025.0           5025.0   36 months    7.84%
# 19        10000.0      10000.0          10000.0   36 months   15.02%
# 20        11200.0      11200.0          11200.0   36 months    7.84%
# 21        20000.0      20000.0          20000.0   36 months    6.67%
# 22        15000.0      15000.0          15000.0   60 months   15.02%
# 23        20000.0      20000.0          20000.0   60 months   13.56%
# 24        12000.0      12000.0          12000.0   36 months    6.11%
# 25        12000.0      12000.0          12000.0   60 months   15.02%
# 26         6400.0       6400.0           6400.0   36 months   10.08%
# 27         9600.0       9600.0           9600.0   36 months   11.55%
# 28        26000.0      26000.0          26000.0   36 months    6.11%
# 29        24200.0      24200.0          24200.0   60 months   14.47%
# ...           ...          ...              ...         ...      ...
# 128164    40000.0      40000.0          39975.0   36 months    6.83%
# 128165    14000.0      14000.0          13975.0   36 months   13.06%
# 128166     9800.0       9800.0           9800.0   36 months   16.46%
# 128167    20000.0      20000.0          20000.0   36 months   11.05%
# 128168    14000.0      14000.0          14000.0   36 months   21.85%
# 128169    40000.0      40000.0          39975.0   36 months    5.31%
# 128170    20000.0      20000.0          19975.0   36 months   15.49%
# 128171    30000.0      30000.0          29975.0   36 months    7.46%
# 128172    36000.0      36000.0          35975.0   36 months    5.31%
# 128173    28000.0      28000.0          27975.0   36 months    6.83%
# 128174    21400.0      21400.0          21400.0   36 months   10.56%
# 128175    24000.0      24000.0          23975.0   36 months   16.46%
# 128176    38000.0      38000.0          38000.0   60 months    7.46%
# 128177    35000.0      35000.0          35000.0   60 months    6.83%
# 128178    24000.0      24000.0          24000.0   60 months   11.05%
# 128179    10000.0      10000.0          10000.0   36 months   10.56%
# 128180    17375.0      17375.0          17375.0   60 months   24.84%
# 128181    20000.0      20000.0          20000.0   36 months   11.05%
# 128182    10000.0      10000.0          10000.0   36 months   12.13%
# 128183    10000.0      10000.0          10000.0   36 months   10.07%
# 128184    40000.0      40000.0          40000.0   60 months   13.06%
# 128185    15000.0      15000.0          15000.0   60 months   18.45%
# 128186    15000.0      15000.0          15000.0   36 months   15.49%
# 128187     5000.0       5000.0           5000.0   36 months   10.56%
# 128188     5000.0       5000.0           5000.0   36 months   16.46%
# 128189    12000.0      12000.0          12000.0   36 months   14.03%
# 128190     5000.0       5000.0           5000.0   36 months    6.19%
# 128191    10000.0      10000.0          10000.0   36 months   11.05%
# 128192    20000.0      20000.0          20000.0   36 months   15.49%
# 128193     4000.0       4000.0           4000.0   36 months   16.46%
#
#         installment grade sub_grade                       emp_title  \
# 0            307.27     A        A2            Customer Service Rep
# 1            770.63     B        B4          Associate Director, IT
# 2            300.13     A        A4                 Branch manager
# 3            557.52     A        A3               Sr. Project Buyer
# 4            378.59     A        A5                         janitor
# 5            154.87     A        A3                             NaN
# 6            395.95     A        A5                  Company driver
# 7            750.83     D        D2              Home Care Provided
# 8            614.53     A        A2      Systems Administrator Lead
# 9            176.14     C        C4                          Driver
# 10           571.22     C        C3            Marketing specialist
# 11           388.62     D        D2                  shipping clerk
# 12           292.46     C        C2    Assistant Manager E-Commerce
# 13          1075.43     A        A2                 Service Advisor
# 14           658.36     C        C2     Customer Service Supervisor
# 15           556.37     D        D5           Relationship Manager
# 16           707.00     A        A4                         Manager
# 17           189.30     A        A5                        Waitress
# 18           157.10     A        A4                      Doc Worker
# 19           346.76     C        C3              Teachers Assistant
# 20           350.15     A        A4  UB APPLICATION SUPPORT ANALYST
# 21           614.53     A        A2                 General Manager
# 22           357.01     C        C3                     Salesperson
# 23           460.82     C        C1               Director of Sales
# 24           365.67     A        A1              PACS Imaging Tech.
# 25           285.61     C        C3                   IT Specialist
# 26           206.76     B        B1       Sales Engineering Support
# 27           316.80     B        B4              Operations Manager
# 28           792.27     A        A1                             CEO
# 29           569.01     C        C2                             NaN
# ...             ...   ...       ...                             ...
# 128164      1231.98     A        A3              accounting manager
# 128165       472.13     C        C1       Administrative Assistant
# 128166       346.77     C        C5                      supervisor
# 128167       655.25     B        B4                           owner
# 128168       533.59     D        D5                             NaN
# 128169      1204.42     A        A1                        Director
# 128170       698.12     C        C4                       Paralegal
# 128171       932.64     A        A4                 Sales Estimater
# 128172      1083.98     A        A1                 Retail Director
# 128173       862.39     A        A3                Regional manager
# 128174       696.16     B        B3                             NaN
# 128175       849.23     C        C5                Registered Nurse
# 128176       760.72     A        A4   Produce buyer - merchandiser
# 128177       690.24     A        A3                              RN
# 128178       522.42     B        B4                             NaN
# 128179       325.31     B        B3                   Bailbondsman
# 128180       508.36     E        E3                             NaN
# 128181       655.25     B        B4      Student Support Specialist
# 128182       332.77     B        B5                  Night watchman
# 128183       323.01     B        B2                     Pipe Fitter
# 128184       911.36     C        C1              Marketing manager
# 128185       384.59     D        D2                             NaN
# 128186       523.59     C        C4                     Crew leader
# 128187       162.66     B        B3                             NaN
# 128188       176.93     C        C5                    Labor Worker
# 128189       410.31     C        C2           Medical Support Staff
# 128190       152.55     A        A2                    Host/cashier
# 128191       327.63     B        B4                        Operator
# 128192       698.12     C        C4                  Client manager
# 128193       141.54     C        C5                         jewelry
#
#        emp_length  ... hardship_payoff_balance_amount  \
# 0       10+ years  ...                            NaN
# 1       10+ years  ...                            NaN
# 2         3 years  ...                            NaN
# 3       10+ years  ...                            NaN
# 4         3 years  ...                            NaN
# 5             NaN  ...                            NaN
# 6         2 years  ...                            NaN
# 7         6 years  ...                            NaN
# 8         4 years  ...                            NaN
# 9       10+ years  ...                            NaN
# 10         1 year  ...                            NaN
# 11      10+ years  ...                            NaN
# 12        2 years  ...                            NaN
# 13        4 years  ...                            NaN
# 14      10+ years  ...                            NaN
# 15        2 years  ...                            NaN
# 16      10+ years  ...                            NaN
# 17      10+ years  ...                            NaN
# 18         1 year  ...                            NaN
# 19        2 years  ...                            NaN
# 20        8 years  ...                            NaN
# 21       < 1 year  ...                            NaN
# 22      10+ years  ...                            NaN
# 23       < 1 year  ...                            NaN
# 24      10+ years  ...                            NaN
# 25      10+ years  ...                            NaN
# 26         1 year  ...                            NaN
# 27        8 years  ...                            NaN
# 28      10+ years  ...                            NaN
# 29            NaN  ...                            NaN
# ...           ...  ...                            ...
# 128164  10+ years  ...                            NaN
# 128165   < 1 year  ...                            NaN
# 128166    8 years  ...                            NaN
# 128167  10+ years  ...                            NaN
# 128168        NaN  ...                            NaN
# 128169    8 years  ...                            NaN
# 128170    4 years  ...                            NaN
# 128171  10+ years  ...                            NaN
# 128172    5 years  ...                            NaN
# 128173    6 years  ...                            NaN
# 128174        NaN  ...                            NaN
# 128175    2 years  ...                            NaN
# 128176     1 year  ...                            NaN
# 128177  10+ years  ...                            NaN
# 128178        NaN  ...                            NaN
# 128179  10+ years  ...                            NaN
# 128180        NaN  ...                            NaN
# 128181  10+ years  ...                            NaN
# 128182  10+ years  ...                            NaN
# 128183    5 years  ...                            NaN
# 128184  10+ years  ...                            NaN
# 128185        NaN  ...                            NaN
# 128186  10+ years  ...                            NaN
# 128187        NaN  ...                            NaN
# 128188    3 years  ...                            NaN
# 128189  10+ years  ...                            NaN
# 128190    4 years  ...                            NaN
# 128191    5 years  ...                            NaN
# 128192  10+ years  ...                            NaN
# 128193    5 years  ...                            NaN
#
#         hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                                NaN           DirectPay                    N
# 1                                NaN                Cash                    N
# 2                                NaN                Cash                    N
# 3                                NaN                Cash                    N
# 4                                NaN                Cash                    N
# 5                                NaN                Cash                    N
# 6                                NaN                Cash                    N
# 7                                NaN                Cash                    N
# 8                                NaN                Cash                    N
# 9                                NaN                Cash                    N
# 10                               NaN                Cash                    N
# 11                               NaN                Cash                    N
# 12                               NaN                Cash                    N
# 13                               NaN                Cash                    N
# 14                               NaN                Cash                    N
# 15                               NaN                Cash                    N
# 16                               NaN                Cash                    N
# 17                               NaN                Cash                    N
# 18                               NaN           DirectPay                    N
# 19                               NaN                Cash                    N
# 20                               NaN                Cash                    N
# 21                               NaN                Cash                    N
# 22                               NaN                Cash                    N
# 23                               NaN                Cash                    N
# 24                               NaN           DirectPay                    N
# 25                               NaN                Cash                    N
# 26                               NaN                Cash                    N
# 27                               NaN                Cash                    N
# 28                               NaN           DirectPay                    N
# 29                               NaN                Cash                    N
# ...                              ...                 ...                  ...
# 128164                           NaN                Cash                    N
# 128165                           NaN                Cash                    N
# 128166                           NaN                Cash                    N
# 128167                           NaN                Cash                    N
# 128168                           NaN                Cash                    N
# 128169                           NaN           DirectPay                    N
# 128170                           NaN                Cash                    N
# 128171                           NaN                Cash                    N
# 128172                           NaN                Cash                    N
# 128173                           NaN                Cash                    N
# 128174                           NaN                Cash                    N
# 128175                           NaN                Cash                    N
# 128176                           NaN                Cash                    N
# 128177                           NaN           DirectPay                    N
# 128178                           NaN                Cash                    N
# 128179                           NaN                Cash                    N
# 128180                           NaN                Cash                    N
# 128181                           NaN                Cash                    N
# 128182                           NaN                Cash                    N
# 128183                           NaN                Cash                    N
# 128184                           NaN                Cash                    N
# 128185                           NaN                Cash                    N
# 128186                           NaN                Cash                    N
# 128187                           NaN                Cash                    N
# 128188                           NaN                Cash                    N
# 128189                           NaN                Cash                    N
# 128190                           NaN                Cash                    N
# 128191                           NaN                Cash                    N
# 128192                           NaN                Cash                    N
# 128193                           NaN                Cash                    N
#
#        debt_settlement_flag_date settlement_status  settlement_date  \
# 0                            NaN               NaN              NaN
# 1                            NaN               NaN              NaN
# 2                            NaN               NaN              NaN
# 3                            NaN               NaN              NaN
# 4                            NaN               NaN              NaN
# 5                            NaN               NaN              NaN
# 6                            NaN               NaN              NaN
# 7                            NaN               NaN              NaN
# 8                            NaN               NaN              NaN
# 9                            NaN               NaN              NaN
# 10                           NaN               NaN              NaN
# 11                           NaN               NaN              NaN
# 12                           NaN               NaN              NaN
# 13                           NaN               NaN              NaN
# 14                           NaN               NaN              NaN
# 15                           NaN               NaN              NaN
# 16                           NaN               NaN              NaN
# 17                           NaN               NaN              NaN
# 18                           NaN               NaN              NaN
# 19                           NaN               NaN              NaN
# 20                           NaN               NaN              NaN
# 21                           NaN               NaN              NaN
# 22                           NaN               NaN              NaN
# 23                           NaN               NaN              NaN
# 24                           NaN               NaN              NaN
# 25                           NaN               NaN              NaN
# 26                           NaN               NaN              NaN
# 27                           NaN               NaN              NaN
# 28                           NaN               NaN              NaN
# 29                           NaN               NaN              NaN
# ...                          ...               ...              ...
# 128164                       NaN               NaN              NaN
# 128165                       NaN               NaN              NaN
# 128166                       NaN               NaN              NaN
# 128167                       NaN               NaN              NaN
# 128168                       NaN               NaN              NaN
# 128169                       NaN               NaN              NaN
# 128170                       NaN               NaN              NaN
# 128171                       NaN               NaN              NaN
['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'revol_bal_joint', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'disbursement_method', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
# find out features with only one unique level and drop them

print(data.columns[data.nunique()==1])
# Out:
# Index(['pymnt_plan', 'policy_code', 'acc_now_delinq', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'tax_liens', 'hardship_flag', 'hardship_type',
#        'hardship_reason', 'hardship_status', 'deferral_term',
#        'hardship_length'],
#       dtype='object')

# %%
print('the unique values in this feature are:', data['pymnt_plan'].unique())
print('the number of missing values is:', data['pymnt_plan'].isna().sum())
# Out:
# the unique values in this feature are: ['n']
# the number of missing values is: 0

# %% [markdown]
# pymnt_plan has only one level, which is 'n', and has no missing values

# %%
headers_unique = list(data.columns[data.nunique()==1])

for header in headers_unique:
    print(header)
    print(data[header].unique())
    print(data[header].isna().sum())
    print()
# Out:
# pymnt_plan
# ['n']
# 0
#
# policy_code
# [1.]
# 0
#
# acc_now_delinq
# [0.]
# 0
#
# num_tl_120dpd_2m
# [ 0. nan]
# 3254
#
# num_tl_30dpd
# [0.]
# 0
#
# tax_liens
# [0.]
# 0
#
# hardship_flag
# ['N']
# 0
#
# hardship_type
# [nan 'INTEREST ONLY-3 MONTHS DEFERRAL']
# 128181
#
# hardship_reason
# [nan 'NATURAL_DISASTER']
# 128181
#
# hardship_status
# [nan 'COMPLETED']
# 128181
#
# deferral_term
# [nan  3.]
# 128181
#
# hardship_length
# [nan  3.]
# 128181

# %% [markdown]
# 128181 people have no hardship records becasue there are 128181 missing values in hardship-related features. It seems that 13 people experienced hardship and have completed it, but it is still an intuitively valuble predictor for indicating a person would likely default, so keep them and drop other unique level features first

# %%
print(headers_unique[:-6])
print(headers_unique[-6:])
# Out:
# ['pymnt_plan', 'policy_code', 'acc_now_delinq', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'tax_liens']
# ['hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_length']

# %%
for header in headers_unique[:-6]:
    data.drop(header, axis=1, inplace=True)

# %% [markdown]
# Since all hardship features are indicating the same thing (3 months length of hardship term), only need to keep one hardship feature (the same for hardship_reason becuase it also only has one level). Keep hardship_status as a categorical feature and name missing values by 'No' as another category

# %%
for header in headers_unique[-6:-3]:
    data.drop(header, axis=1, inplace=True)

for header in headers_unique[-2:]:
    data.drop(header, axis=1, inplace=True)

# %%
data['hardship_status'].fillna('No',inplace=True)

# %%
print(data['hardship_status'].unique())
print(data['hardship_status'].isna().sum())
# Out:
# ['No' 'COMPLETED']
# 0

# %%
data.shape
# Out:
# (128194, 132)

# %%
# find out features that have missing values and impute them

data.isna().sum()
# Out:
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# emp_title                                      13437
# emp_length                                     10387
# home_ownership                                     0
# annual_inc                                         0
# verification_status                                0
# issue_d                                            0
# loan_status                                        0
# url                                           128194
# desc                                          128194
# purpose                                            0
# title                                              0
# zip_code                                           0
# addr_state                                         0
# dti                                              307
# delinq_2yrs                                        0
# earliest_cr_line                                   0
# inq_last_6mths                                     0
# mths_since_last_delinq                         71389
# mths_since_last_record                        112487
# open_acc                                           0
# pub_rec                                            0
# revol_bal                                          0
#                                                ...
# total_il_high_credit_limit                         0
# revol_bal_joint                               110409
# sec_app_earliest_cr_line                      110409
# sec_app_inq_last_6mths                        110409
# sec_app_mort_acc                              110409
# sec_app_open_acc                              110409
# sec_app_revol_util                            110719
# sec_app_open_act_il                           110409
# sec_app_num_rev_accts                         110409
# sec_app_chargeoff_within_12_mths              110409
# sec_app_collections_12_mths_ex_med            110409
# sec_app_mths_since_last_major_derog           122582
# hardship_status                                    0
# hardship_amount                               128181
# hardship_start_date                           128181
# hardship_end_date                             128181
# payment_plan_start_date                       128181
# hardship_dpd                                  128181
# hardship_loan_status                          128181
# orig_projected_additional_accrued_interest    128181
# hardship_payoff_balance_amount                128181
# hardship_last_payment_amount                  128181
# disbursement_method                                0
# debt_settlement_flag                               0
# debt_settlement_flag_date                     128179
# settlement_status                             128179
# settlement_date                               128179
# settlement_amount                             128179
# settlement_percentage                         128179
# settlement_term                               128179
# Length: 132, dtype: int64

# %%
headers_na = list(data.columns[data.isna().sum() > 0])
print('The number of features that have missing values are:',len(headers_na))
print('The features that have missing values are:')
print(headers_na)
# Out:
# The number of features that have missing values are: 54
# The features that have missing values are:
# ['emp_title', 'emp_length', 'url', 'desc', 'dti', 'mths_since_last_delinq', 'mths_since_last_record', 'revol_util', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'mths_since_rcnt_il', 'il_util', 'all_util', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'revol_bal_joint', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %% [markdown]
# impute hardship-related features for first

# %%
headers_na_hard = ['hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_dpd', 
                   'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount',
                   'hardship_last_payment_amount' ]

# %%
for header in headers_na_hard:
    print(header)
    print(data[header].unique())
    print(data[header].isna().sum())
    print()
# Out:
# hardship_amount
# [   nan 203.67 378.9  126.27 119.59 243.56 159.94 241.9  134.81 194.82
#   55.04 215.7  248.46 109.26]
# 128181
#
# hardship_start_date
# [nan 'Oct-2018' 'Nov-2018' 'Sep-2018']
# 128181
#
# hardship_end_date
# [nan 'Dec-2018' 'Jan-2019' 'Feb-2019']
# 128181
#
# payment_plan_start_date
# [nan 'Oct-2018' 'Nov-2018' 'Dec-2018']
# 128181
#
# hardship_dpd
# [nan  0. 18.]
# 128181
#
# hardship_loan_status
# [nan 'Issued' 'Current' 'Late (31-120 days)']
# 128181
#
# orig_projected_additional_accrued_interest
# [    nan  611.01 1136.7   378.81  358.77  730.68  479.82  725.7   404.43
#   584.46  165.12  647.1   745.38  327.78]
# 128181
#
# hardship_payoff_balance_amount
# [     nan 40149.35 23090.22  8096.8   9649.7  12701.26 19071.77 19495.24
#   9674.48 12492.2   5767.68 15414.46 23553.11  5932.38]
# 128181
#
# hardship_last_payment_amount
# [       nan 1.0100e+00 1.2100e+00 2.9283e+02 3.4643e+02 1.0000e-01
#  1.9000e-01 4.7013e+02 2.0000e-01 3.2613e+02 1.9795e+02 2.4000e-01
#  5.4237e+02 3.6648e+02]
# 128181

# %%
print(data['hardship_status'].unique())
print(data['hardship_status'].isna().sum())
# Out:
# ['No' 'COMPLETED']
# 0

# %% [markdown]
# drop hardship related date features

# %%
data.drop(labels=['hardship_start_date','hardship_end_date','payment_plan_start_date',
                              'hardship_dpd'],axis=1,inplace=True)

# %% [markdown]
# impute missing values in hardship_amount, orig_projected_additional_accrued_interest, hardship_payoff_balance_amount, and hardship_last_payment_amount by 0 (float), and name missing values in hardship_loan_status by 'No' as a new category

# %%
data['hardship_loan_status'].fillna('No',inplace=True)
data['hardship_amount'].fillna(0.,inplace=True)
data['orig_projected_additional_accrued_interest'].fillna(0.,inplace=True)
data['hardship_payoff_balance_amount'].fillna(0.,inplace=True)
data['hardship_last_payment_amount'].fillna(0.,inplace=True)

# %%
data.groupby(by=['hardship_loan_status']).size()
# Out:
# hardship_loan_status
# Current                    9
# Issued                     3
# Late (31-120 days)         1
# No                    128181
# dtype: int64

# %%
data.shape
# Out:
# (128194, 128)

# %% [markdown]
# then, impute settlement-related features

# %%
print(data['debt_settlement_flag'].unique())
print(data['debt_settlement_flag'].isna().sum())
# Out:
# ['N' 'Y']
# 0

# %%
headers_na_settle = ['debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 
                     'settlement_percentage', 'settlement_term']

# %%
for header in headers_na_settle:
    print(header)
    print(data[header].unique())
    print(data[header].isna().sum())
    print()
# Out:
# debt_settlement_flag_date
# [nan 'Feb-2019' 'Dec-2018' 'Jan-2019' 'Nov-2018']
# 128179
#
# settlement_status
# [nan 'ACTIVE' 'COMPLETE' 'BROKEN']
# 128179
#
# settlement_date
# [nan 'Feb-2019' 'Dec-2018' 'Jan-2019' 'Nov-2018']
# 128179
#
# settlement_amount
# [   nan 23506.  3422. 13175.  5180.  1059. 14333.  5694.  3332.  3852.
#   3064. 12539. 16278.  5520. 21824.  5126.]
# 128179
#
# settlement_percentage
# [  nan 65.   65.01 60.   64.97 60.01 64.99]
# 128179
#
# settlement_term
# [nan 18.  6. 14.]
# 128179

# %%
data.groupby(by=['settlement_date']).size()
# Out:
# settlement_date
# Dec-2018    3
# Feb-2019    8
# Jan-2019    2
# Nov-2018    2
# dtype: int64

# %%
data.groupby(by=['debt_settlement_flag_date']).size()
# Out:
# debt_settlement_flag_date
# Dec-2018    2
# Feb-2019    8
# Jan-2019    3
# Nov-2018    2
# dtype: int64

# %%
data.groupby(by=['settlement_percentage']).size()
# Out:
# settlement_percentage
# 60.00    1
# 60.01    1
# 64.97    1
# 64.99    1
# 65.00    9
# 65.01    2
# dtype: int64

# %%
data.groupby(by=['settlement_status']).size()
# Out:
# settlement_status
# ACTIVE      13
# BROKEN       1
# COMPLETE     1
# dtype: int64

# %%
settle_index = list(data.index[data['debt_settlement_flag_date'].isna()==False])
print(settle_index)
# Out:
# [15502, 27323, 54006, 65682, 72383, 80739, 82483, 88882, 90178, 106112, 112735, 120122, 123343, 124676, 125137]

# %%
charged_off_index = list(data.index[data['loan_status'] == 'Charged Off'])

# %%
print(any(i in charged_off_index for i in settle_index))
print(all(i in charged_off_index for i in settle_index))
# Out:
# True
# False

# %% [markdown]
# Not all people on settlement plan are marked as charged off in loan_status

# %%
settle_charge=[]
settle_not_in_charge=[]
for i in settle_index:
    if i in charged_off_index:
        settle_charge.append(i)
    else:
        settle_not_in_charge.append(i)
print(settle_charge)
print(settle_not_in_charge)
# Out:
# [82483, 88882, 90178, 106112, 120122, 125137]
# [15502, 27323, 54006, 65682, 72383, 80739, 112735, 123343, 124676]

# %%
head = ['settlement_status', 'loan_status']

# %%
for i in settle_not_in_charge:
    print(data[head][i:i+1])
# Out:
#       settlement_status         loan_status
# 15502            ACTIVE  Late (31-120 days)
#       settlement_status         loan_status
# 27323            ACTIVE  Late (31-120 days)
#       settlement_status         loan_status
# 54006            ACTIVE  Late (31-120 days)
#       settlement_status         loan_status
# 65682            ACTIVE  Late (31-120 days)
#       settlement_status loan_status
# 72383            ACTIVE     Current
#       settlement_status         loan_status
# 80739            ACTIVE  Late (31-120 days)
#        settlement_status         loan_status
# 112735            ACTIVE  Late (31-120 days)
#        settlement_status         loan_status
# 123343            ACTIVE  Late (31-120 days)
#        settlement_status         loan_status
# 124676            ACTIVE  Late (31-120 days)

# %% [markdown]
# people on settlement plan are also in other loan status besides being charged off

# %%
data.groupby(by=['debt_settlement_flag']).size()
# Out:
# debt_settlement_flag
# N    128179
# Y        15
# dtype: int64

# %% [markdown]
# drop settlement date related features

# %%
data.drop(labels=['debt_settlement_flag_date','settlement_date'],axis=1,inplace=True)

# %%
print(data['settlement_amount'].unique().dtype)
print(data['settlement_percentage'].unique().dtype)
print(data['settlement_term'].unique().dtype)
# Out:
# float64
# float64
# float64

# %%
data['settlement_status'].fillna('No',inplace=True)
data['settlement_amount'].fillna(0.,inplace=True)
data['settlement_percentage'].fillna(0.,inplace=True)
data['settlement_term'].fillna(0.,inplace=True)

# %%
data.shape
# Out:
# (128194, 126)

# %%
# inspect remaining features that have missing values

headers_na_rest = list(data.columns[data.isna().sum() > 0])
print(len(headers_na_rest),'remaining features to be imputed')
data[headers_na_rest].isna().sum()
# Out:
# 39 remaining features to be imputed
# emp_title                               13437
# emp_length                              10387
# url                                    128194
# desc                                   128194
# dti                                       307
# mths_since_last_delinq                  71389
# mths_since_last_record                 112487
# revol_util                                129
# last_pymnt_d                              141
# next_pymnt_d                             8063
# last_credit_pull_d                          4
# mths_since_last_major_derog             98364
# annual_inc_joint                       110409
# dti_joint                              110409
# verification_status_joint              112465
# mths_since_rcnt_il                       4611
# il_util                                 20514
# all_util                                   29
# avg_cur_bal                                12
# bc_open_to_buy                           1647
# bc_util                                  1696
# mo_sin_old_il_acct                       4611
# mths_since_recent_bc                     1550
# mths_since_recent_bc_dlq               102769
# mths_since_recent_inq                   16016
# mths_since_recent_revol_delinq          91113
# pct_tl_nvr_dlq                              1
# percent_bc_gt_75                         1649
# revol_bal_joint                        110409
# sec_app_earliest_cr_line               110409
# sec_app_inq_last_6mths                 110409
# sec_app_mort_acc                       110409
# sec_app_open_acc                       110409
# sec_app_revol_util                     110719
# sec_app_open_act_il                    110409
# sec_app_num_rev_accts                  110409
# sec_app_chargeoff_within_12_mths       110409
# sec_app_collections_12_mths_ex_med     110409
# sec_app_mths_since_last_major_derog    122582
# dtype: int64

# %% [markdown]
# impute features that are related to secondary or joint applicant

# %%
headers_na_sec = ['sec_app_earliest_cr_line', 'sec_app_inq_last_6mths','sec_app_mort_acc','sec_app_open_acc','sec_app_revol_util',
                 'sec_app_open_act_il','sec_app_num_rev_accts','sec_app_chargeoff_within_12_mths','sec_app_collections_12_mths_ex_med',
                 'sec_app_mths_since_last_major_derog','revol_bal_joint','verification_status_joint','dti_joint','annual_inc_joint']

# %%
for header in headers_na_sec:
    print(header)
    print(data[header].unique())
    print()
# Out:
# sec_app_earliest_cr_line
# [nan 'Mar-1973' 'Apr-2002' 'Nov-2004' 'May-2006' 'Dec-2000' 'May-2011'
#  'Sep-2002' 'Oct-1996' 'Nov-2005' 'Jan-2001' 'Jul-2005' 'Nov-2006'
#  'Aug-2003' 'Jul-2001' 'Oct-2008' 'Sep-2016' 'Sep-2004' 'Jun-2007'
#  'Jan-2014' 'Mar-2002' 'Sep-1993' 'Oct-2006' 'Feb-2005' 'May-2003'
#   55.  76. 111.  83.  15. 107.  91.  82.  89. 105.  90.  84. 127.  99.
#   85. 108. 123.  86. 103. 119.  87. 104. 115. 100. 118. 132. 109.  94.
#  102. 143.  95. 125. 124. 106. 101.  98. 129.]
#
# revol_bal_joint
# [   nan 54654. 75938. ... 33630. 61154. 59269.]
#
# verification_status_joint
# [nan 'Verified' 'Not Verified' 'Source Verified']
#
# dti_joint
# [  nan 34.47 24.83 ...  5.54 36.99 31.22]
#
# annual_inc_joint
# [    nan  81648. 110000. ... 161300. 174950.  45880.]

# %%
data[headers_na_sec].isna().sum()
# Out:
# sec_app_earliest_cr_line               110409
# sec_app_inq_last_6mths                 110409
# sec_app_mort_acc                       110409
# sec_app_open_acc                       110409
# sec_app_revol_util                     110719
# sec_app_open_act_il                    110409
# sec_app_num_rev_accts                  110409
# sec_app_chargeoff_within_12_mths       110409
# sec_app_collections_12_mths_ex_med     110409
# sec_app_mths_since_last_major_derog    122582
# revol_bal_joint                        110409
# verification_status_joint              112465
# dti_joint                              110409
# annual_inc_joint                       110409
# dtype: int64

# %% [markdown]
# sec_app_revol_util, sec_app_mths_since_last_major_derog, and verification_status_joint have different number of NA than others. sec_app_mths_since_last_major_derog is ok becuase it may not apply to some secondary applicants. examine the other two features

# %%
sec_index_base1 = list(data.index[data['sec_app_earliest_cr_line'].isna()==False])
sec_index_base2 = list(data.index[data['sec_app_mort_acc'].isna()==False])

# %%
all(i in sec_index_base1 for i in sec_index_base2)
# Out:
# True

# %% [markdown]
# confirm indexes of features that have 110409 NAs matching first, and use the Non-NAs' indexes as baseline for comparison; confirm if all indexes of Non-NAs in sec_app_revol_util and verification_status_joint are in baseline

# %%
sec_index_revol = list(data.index[data['sec_app_revol_util'].isna()==False])
sec_index_veri = list(data.index[data['verification_status_joint'].isna()==False])

# %%
sec_diff_revol=[]
sec_diff_veri=[]
for i in sec_index_base1:
    if i not in sec_index_revol:
        sec_diff_revol.append(i)

for i in sec_index_base1:
    if i not in sec_index_veri:
        sec_diff_veri.append(i)
        
print(len(sec_index_base1)-len(sec_index_revol)==len(sec_diff_revol))     
print(len(sec_index_base1)-len(sec_index_veri)==len(sec_diff_veri))
# Out:
# True
# True

# %% [markdown]
# confirmed all indexes in sec_app_revol_util and verification_status_joint are in baseline

# %%
data.groupby(by=['verification_status_joint']).size()
# Out:
# verification_status_joint
# Not Verified       6827
# Source Verified    5601
# Verified           3301
# dtype: int64

# %%
any(data['sec_app_revol_util']==0.)
# Out:
# True

# %%
print(data['sec_app_revol_util'].median())
print(data['sec_app_revol_util'].mean())
print(data['sec_app_revol_util'].mode())
# Out:
# 58.4
# 56.37079256080114
# 0    0.0
# dtype: float64

# %% [markdown]
# Since there are data=0 in sec_app_revol_util, cannot use 0 to impute missing values of people not having secondary applicant, use -1 instead. Use median to impute missing values of people having secondary applicant.
# Use 'Not Verified' to impute verification_status_joint for people having secondary applicant, and 'No' to impute people not having secondary applicant

# %%
for i in sec_diff_revol:
    data['sec_app_revol_util'][i:i+1].fillna(data['sec_app_revol_util'].median(),inplace=True)

# %%
data['sec_app_revol_util'].fillna(-1.,inplace=True)

# %%
for i in sec_diff_veri:
    data['verification_status_joint'][i:i+1].fillna('Not Verified',inplace=True)

# %%
data['verification_status_joint'].fillna('No',inplace=True)

# %%
data.groupby(by=['verification_status_joint']).size()
# Out:
# verification_status_joint
# No                 110409
# Not Verified         8883
# Source Verified      5601
# Verified             3301
# dtype: int64

# %%
data['sec_app_mths_since_last_major_derog'].fillna(-1.,inplace=True)

# %% [markdown]
# now impute the rest secondary applicant related features by -1 because they are all numeric predictors, except for sec_app_earliest_cr_line because it is a date type predictor

# %%
for header in headers_na_sec:
    if header not in ['sec_app_revol_util','verification_status_joint','sec_app_mths_since_last_major_derog', 'sec_app_earliest_cr_line']:
        data[header].fillna(-1.,inplace=True)

# %%
data['sec_app_earliest_cr_line'].dtype
# Out:
# dtype('O')

# %% [markdown]
# now deal with date type predictor sec_app_earliest_cr_line; impute it with another category, say 'Jan-1900'

# %%
data['sec_app_earliest_cr_line'].fillna('Jan-1900',inplace=True)

# %%
# Again, inspect remaining features that have missing values

headers_na_rest1 = list(data.columns[data.isna().sum() > 0])
print(len(headers_na_rest1),'remaining features to be imputed')
data[headers_na_rest1].isna().sum()
# Out:
# 25 remaining features to be imputed
# emp_title                          13437
# emp_length                         10387
# url                               128194
# desc                              128194
# dti                                  307
# mths_since_last_delinq             71389
# mths_since_last_record            112487
# revol_util                           129
# last_pymnt_d                         141
# next_pymnt_d                        8063
# last_credit_pull_d                     4
# mths_since_last_major_derog        98364
# mths_since_rcnt_il                  4611
# il_util                            20514
# all_util                              29
# avg_cur_bal                           12
# bc_open_to_buy                      1647
# bc_util                             1696
# mo_sin_old_il_acct                  4611
# mths_since_recent_bc                1550
# mths_since_recent_bc_dlq          102769
# mths_since_recent_inq              16016
# mths_since_recent_revol_delinq     91113
# pct_tl_nvr_dlq                         1
# percent_bc_gt_75                    1649
# dtype: int64

# %% [markdown]
# drop url and desc becuase the two columns are entirely missing

# %%
data.drop(labels=['url','desc'], axis=1, inplace=True)

# %%
print(data['emp_title'].unique())
print(data['emp_title'].nunique())
# Out:
# ['Customer Service Rep' 'Associate Director, IT' 'Branch manager ' ...
#  'Medical Support Staff' 'Host/cashier' 'jewelry']
# 44627

# %% [markdown]
# drop emp_title because of too many levels

# %%
data.drop('emp_title', axis=1,inplace=True)

# %%
data.shape
# Out:
# (128194, 123)

# %% [markdown]
# inspect features that have less than 1000 missing values, impute numeric predictor by mean or median, categorical by mode

# %%
data['dti'].dtype
# Out:
# dtype('float64')

# %%
print(data['dti'].mean())
print(data['dti'].median())
# Out:
# 19.81038401088461
# 17.81

# %%
data['dti'].fillna(data['dti'].mean(),inplace=True)

# %%
print(data['revol_util'].dtype)
print(data['revol_util'][:10])
# Out:
# object
# 0    24.1%
# 1    48.8%
# 2    10.8%
# 3    13.2%
# 4    26.7%
# 5       8%
# 6     3.2%
# 7     3.8%
# 8    35.9%
# 9    74.1%
# Name: revol_util, dtype: object

# %%
data['revol_util'] = data['revol_util'].str.rstrip('%').astype('float')

# %%
print(data['revol_util'][:10])
# Out:
# 0    24.1
# 1    48.8
# 2    10.8
# 3    13.2
# 4    26.7
# 5     8.0
# 6     3.2
# 7     3.8
# 8    35.9
# 9    74.1
# Name: revol_util, dtype: float64

# %%
print(data['revol_util'].mean())
print(data['revol_util'].median())
# Out:
# 44.45021668683872
# 42.7

# %%
data['revol_util'].fillna(data['revol_util'].mean(),inplace=True)

# %%
print(data['last_pymnt_d'].dtype)
# Out:
# object

# %%
data.groupby(by=['last_pymnt_d']).size()
# Out:
# last_pymnt_d
# Aug-2018       837
# Dec-2018      1678
# Feb-2019    116381
# Jan-2019      4633
# Jul-2018       222
# Nov-2018      1613
# Oct-2018      1562
# Sep-2018      1127
# dtype: int64

# %%
data['last_pymnt_d'].fillna('Feb-2019',inplace=True)

# %%
print(data['last_credit_pull_d'].dtype)
# Out:
# object

# %%
data.groupby(by=['last_credit_pull_d']).size()
# Out:
# last_credit_pull_d
# Aug-2018       565
# Dec-2018      1048
# Feb-2019    122163
# Jan-2019      1803
# Jul-2018       335
# Jun-2018        53
# Nov-2018       876
# Oct-2018       687
# Sep-2018       660
# dtype: int64

# %%
data['last_credit_pull_d'].fillna('Feb-2019',inplace=True)

# %%
print(data['all_util'].dtype)
# Out:
# float64

# %%
print(data['all_util'].mean())
print(data['all_util'].median())
# Out:
# 54.353747122849455
# 55.0

# %%
data['all_util'].fillna(data['all_util'].mean(),inplace=True)

# %%
print(data['avg_cur_bal'].dtype)
# Out:
# float64

# %%
print(data['avg_cur_bal'].mean())
print(data['avg_cur_bal'].median())
# Out:
# 13695.71962522039
# 7080.0

# %%
data['avg_cur_bal'].fillna(data['avg_cur_bal'].median(),inplace=True)

# %%
print(data['pct_tl_nvr_dlq'].dtype)
# Out:
# float64

# %%
print(data['pct_tl_nvr_dlq'].mean())
print(data['pct_tl_nvr_dlq'].median())
# Out:
# 94.58931610930394
# 100.0

# %%
data['pct_tl_nvr_dlq'].fillna(data['pct_tl_nvr_dlq'].mean(),inplace=True)

# %% [markdown]
# inspect features that have more than 1000 missing values; use other features to predict missing values

# %%
headers_na_rest2 = list(data.columns[data.isna().sum() > 0])
print(len(headers_na_rest2),'remaining features to be imputed')
data[headers_na_rest2].isna().sum()
# Out:
# 15 remaining features to be imputed
# emp_length                         10387
# mths_since_last_delinq             71389
# mths_since_last_record            112487
# next_pymnt_d                        8063
# mths_since_last_major_derog        98364
# mths_since_rcnt_il                  4611
# il_util                            20514
# bc_open_to_buy                      1647
# bc_util                             1696
# mo_sin_old_il_acct                  4611
# mths_since_recent_bc                1550
# mths_since_recent_bc_dlq          102769
# mths_since_recent_inq              16016
# mths_since_recent_revol_delinq     91113
# percent_bc_gt_75                    1649
# dtype: int64

# %%
for header in headers_na_rest2:
    if data[header].dtype != "float64":
        print(header)
        print(data[header].dtype)
# Out:
# emp_length
# object
# next_pymnt_d
# object

# %%
data.shape
# Out:
# (128194, 123)

# %%
data.to_csv("15_more_to_be_imputed_data.csv",index=False)
